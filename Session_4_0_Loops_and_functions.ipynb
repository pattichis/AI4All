# %% [markdown]
# <a href="https://colab.research.google.com/github/pattichis/AI4All/blob/main/Session_4_0_Loops_and_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Functions in Python

# %% [markdown]
# ```
# def my_fun(arg1, arg2):
#   Body of the function
# ```

# %%
# Explain the answer for the following
def sub(x, y):
  return x-y

x = 1
y = 2
print(f"sub({x}, {y})=", sub(x, y))

# %% [markdown]
# Use keyword names to call functions in arbitrary order:
# ```
# def function_name(arg1, arg2, arg3):
#   Function_body
#
# function_name(arg3=val3, arg1=val1, arg2=val2)
# ```

# %%
def fun(a, b, c):
  print(f"a={a}, b={b}, c={c}")

print("They all produce the same result!")
fun(1, 2, 3)        # Assigning a, b, c based on order.
fun(c=3, b=2, a=1)  # Use keywords.
fun(b=2, a=1, c=3)

# Call using another order and verify that you are getting the same result

# %% [markdown]
# # Create a function assignment

# %%
# Write a function that adds two numbers.
# Your function should be called add(a,b)

# Note: AI may automatically fill it up for you!
# To make sure you understand it, explain your code to your group.

# Define the function here:


# Test your function:
a = 1
b = 2
result = add(a, b)
print(f"add({a}, {b}) = {result}"

# Provide one more example for using your function:
